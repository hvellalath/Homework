# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import csv

# Import API key
from api_key import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=50)
lngs = np.random.uniform(low=-180.000, high=180.000, size=50)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
    print(f"city is {city} and lat{lat_lng[0]}-lng{lat_lng[1]}")

# Print the city count to confirm sufficient count
len(cities)
# Out:
# city is khatanga and lat87.86111285115632-lng93.92055894396628
# city is presidencia roque saenz pena and lat-26.35541740912258-lng-62.02610955602444
# city is hilo and lat27.85420651504988-lng-148.90352816548034
# city is talnakh and lat76.30363632891479-lng90.79604336599385
# city is hilo and lat23.38636195323589-lng-139.8153967621451
# city is santa isabel do rio negro and lat1.3426871627102486-lng-64.07846360903733
# city is ushuaia and lat-75.30090115662686-lng-80.9447822348968
# city is nioro and lat15.209842494325542-lng-9.33403958240143
# city is husavik and lat77.1825781073735-lng-7.809416673636548
# city is vaini and lat-45.59921553202573-lng-174.29387629474098
# city is mecca and lat21.836482942146574-lng41.5028384629145
# city is okhotsk and lat58.27100860730846-lng146.40440279115046
# city is bluff and lat-64.24605272147092-lng156.07425709616342
# city is port alfred and lat-88.4757591739339-lng56.964191862321115
# city is puerto ayora and lat-10.789769858631928-lng-111.96738412205103
# city is letterkenny and lat54.924999217058115-lng-7.689262169701834
# city is hithadhoo and lat-15.67814856727307-lng84.7836955587648
# city is hermanus and lat-66.59577264648146-lng13.706330335412446
# city is ushuaia and lat-88.73457354495993-lng-68.24084049785904
# city is torbay and lat36.641804160544496-lng-48.128557184052056
# city is illoqqortoormiut and lat72.13077049262105-lng-24.48989759888073
# city is carnarvon and lat-23.39409656984337-lng104.60416152525363
# city is saint-philippe and lat-37.13880951110389-lng58.940013255811124
# city is porto novo and lat15.349141320961706-lng-30.920010078928897
# city is altamira and lat-3.490754377506917-lng-52.00639050683509
# city is vanimo and lat2.402273676498794-lng140.48841623485436
# city is sabang and lat6.2850234371032485-lng94.18976004975116
# city is severo-kurilsk and lat34.00379136296675-lng165.19536127972265
# city is chuy and lat-54.239956176134804-lng-33.112416286247054
# city is hobart and lat-65.93582478711501-lng147.30645697881937
# city is saint-francois and lat17.84304090453557-lng-56.266670920803904
# city is tomatlan and lat16.132417812732527-lng-109.6879215628105
# city is hilo and lat4.359248752718258-lng-154.35874529279627
# city is barentsburg and lat87.39688919618732-lng6.348633778213099
# city is katherine and lat-15.699420113988566-lng132.0005044200749
# city is rikitea and lat-33.91317630065648-lng-131.12116486767007
# city is luanda and lat-8.793736212077633-lng9.608244222434593
# city is kovur and lat14.128452534506195-lng80.63394520798494
# city is la palma and lat6.245022238490492-lng-80.20264696677559
# city is sibu and lat2.9083014280417103-lng111.50888741459556
# city is new norfolk and lat-50.90637093192344-lng137.6155440658045
# city is boshnyakovo and lat50.17989849809763-lng141.08181452572768
# city is avarua and lat-38.14749926441474-lng-160.24125532078676
# city is kapaa and lat18.125345375374152-lng-179.00534965252965
# city is chokurdakh and lat80.34140186457705-lng153.75302957085285
# city is port elizabeth and lat-50.625019154941015-lng27.21900463371324
# city is ponta do sol and lat34.668655920708105-lng-20.318630903632595
# city is mataura and lat-30.4732835035611-lng-152.06366040164113
# city is luchow and lat53.05078524305932-lng11.330676256613032
# city is constitucion and lat20.25640481443172-lng-116.88715272293481
# 47

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'Imperial'

#create a list of lists to store city details
detailCity = []

#loop through each city
#add a counter for number of records
i = 0
for cityName in cities:
    #print (f'processing city: {cityName}')
    query_url = f"{url}appid={api_key}&q={cityName}&units={units}"
    response = requests.get(query_url)
    data = response.json()
    if data['cod']==200:
        id = str(data['id'])
        name =  data['name']
        details = {}
        details['Name']  = data['name']
        details['Cloudiness'] = data['clouds']['all']
        details['Country'] = data['sys']['country']
        details['Lat'] = data['coord']['lat']
        details['Lng'] = data['coord']['lon']
        details['Date'] =data['dt']
        details['Max Temp'] = data['main']['temp_max']
        details['Humidity'] = data['main']['humidity']
        details['WindSpeed'] = data['wind']['speed']
        i +=  1
        detailCity.append(details)
        print (f" processing record: {i} | ID = {id} city name {name}")
        #pprint(data)
    else:
        print (f"No city data for : {name}")
# Out:
#  processing record: 1 | ID = 5861897 city name Fairbanks
#  processing record: 2 | ID = 1279027 city name Alibag
#  processing record: 3 | ID = 546105 city name Nikolskoye
#  processing record: 4 | ID = 4030556 city name Rikitea
#  processing record: 5 | ID = 1214488 city name Meulaboh
#  processing record: 6 | ID = 964432 city name Port Alfred
#  processing record: 7 | ID = 3137469 city name Sorland
#  processing record: 8 | ID = 2208248 city name Kaitangata
#  processing record: 9 | ID = 3031582 city name Saint-Augustin
#  processing record: 10 | ID = 3833367 city name Ushuaia
#  processing record: 11 | ID = 750317 city name Bulancak
#  processing record: 12 | ID = 2381334 city name Atar
#  processing record: 13 | ID = 3874787 city name Punta Arenas
#  processing record: 14 | ID = 1006984 city name East London
#  processing record: 15 | ID = 2069194 city name Jamestown
#  processing record: 16 | ID = 3863379 city name Mar del Plata
#  processing record: 17 | ID = 3840300 city name Presidencia Roque Saenz Pena
#  processing record: 18 | ID = 6201424 city name Mataura
# No city data for : Mataura
#  processing record: 19 | ID = 3625066 city name Zaraza
#  processing record: 20 | ID = 2013279 city name Vostok
#  processing record: 21 | ID = 2027196 city name Balakhninskiy
#  processing record: 22 | ID = 5848280 city name Kapaa
#  processing record: 23 | ID = 3652764 city name Puerto Ayora
#  processing record: 24 | ID = 2075265 city name Busselton
#  processing record: 25 | ID = 2175403 city name Bluff
#  processing record: 26 | ID = 1856392 city name Muroto
#  processing record: 27 | ID = 1849876 city name Tateyama
#  processing record: 28 | ID = 57000 city name Hobyo
#  processing record: 29 | ID = 3463237 city name Florianopolis
#  processing record: 30 | ID = 3424607 city name Tasiilaq
#  processing record: 31 | ID = 5367788 city name Lompoc
#  processing record: 32 | ID = 3418910 city name Upernavik
#  processing record: 33 | ID = 1808857 city name Hanzhong
#  processing record: 34 | ID = 6170031 city name Tuktoyaktuk
#  processing record: 35 | ID = 3668175 city name El Silencio
#  processing record: 36 | ID = 934322 city name Mahebourg
#  processing record: 37 | ID = 3577154 city name Oranjestad
#  processing record: 38 | ID = 1282256 city name Hithadhoo
#  processing record: 39 | ID = 3471451 city name Arraial do Cabo
#  processing record: 40 | ID = 3026644 city name Souillac
# No city data for : Souillac
#  processing record: 41 | ID = 2019323 city name Nerchinskiy Zavod
#  processing record: 42 | ID = 3833859 city name Barrow
# No city data for : Barrow
#  processing record: 43 | ID = 1861416 city name Ishigaki
#  processing record: 44 | ID = 2508813 city name Adrar
#  processing record: 45 | ID = 3679277 city name Caceres
#  processing record: 46 | ID = 3896218 city name Castro
# No city data for : Castro
#  processing record: 47 | ID = 2633414 city name Yarmouth
#  processing record: 48 | ID = 5223358 city name Middletown
#  processing record: 49 | ID = 2110227 city name Butaritari
#  processing record: 50 | ID = 3366880 city name Hermanus
# No city data for : Hermanus
#  processing record: 51 | ID = 4031574 city name Provideniya
#  processing record: 52 | ID = 286621 city name Salalah
# No city data for : Salalah
#  processing record: 53 | ID = 2641434 city name Northam
#  processing record: 54 | ID = 5969785 city name Hamilton
#  processing record: 55 | ID = 145724 city name Lucapa
#  processing record: 56 | ID = 2122605 city name Okhotsk
#  processing record: 57 | ID = 3395458 city name Maragogi
#  processing record: 58 | ID = 915471 city name Kalabo
#  processing record: 59 | ID = 1851279 city name Taga
#  processing record: 60 | ID = 2094342 city name Kavieng
#  processing record: 61 | ID = 780687 city name Berlevag
#  processing record: 62 | ID = 6149374 city name Slave Lake
# No city data for : Slave Lake
#  processing record: 63 | ID = 2409914 city name Bonthe
#  processing record: 64 | ID = 1273574 city name Vaini
#  processing record: 65 | ID = 3985710 city name Cabo San Lucas
#  processing record: 66 | ID = 2155415 city name New Norfolk
#  processing record: 67 | ID = 5106834 city name Albany
#  processing record: 68 | ID = 2128382 city name Rumoi
#  processing record: 69 | ID = 8010472 city name Belmonte
#  processing record: 70 | ID = 5962442 city name Goderich
#  processing record: 71 | ID = 3844421 city name Russell
#  processing record: 72 | ID = 691469 city name Tokmak
#  processing record: 73 | ID = 3374210 city name Sao Filipe
#  processing record: 74 | ID = 3526662 city name Teya
#  processing record: 75 | ID = 2332459 city name Lagos
#  processing record: 76 | ID = 2123814 city name Leningradskiy
# No city data for : Leningradskiy
#  processing record: 77 | ID = 229112 city name Moroto
#  processing record: 78 | ID = 2037886 city name Dandong
#  processing record: 79 | ID = 2918752 city name Gotha
#  processing record: 80 | ID = 3838233 city name Salta
#  processing record: 81 | ID = 2110460 city name Yuzawa
#  processing record: 82 | ID = 1712961 city name Gigmoto
#  processing record: 83 | ID = 5380437 city name Pacific Grove
#  processing record: 84 | ID = 650225 city name Kuopio
#  processing record: 85 | ID = 1244926 city name Hambantota
#  processing record: 86 | ID = 262462 city name Saint George
#  processing record: 87 | ID = 2112802 city name Hasaki
#  processing record: 88 | ID = 2026786 city name Berezovyy
#  processing record: 89 | ID = 1795424 city name Huilong
#  processing record: 90 | ID = 4696310 city name Harper
#  processing record: 91 | ID = 2017155 city name Saskylakh
#  processing record: 92 | ID = 6165406 city name Thompson
#  processing record: 93 | ID = 3385736 city name Upanema
#  processing record: 94 | ID = 3573739 city name Esperance
#  processing record: 95 | ID = 2120591 city name Tilichiki
#  processing record: 96 | ID = 2191562 city name Dunedin
#  processing record: 97 | ID = 3831208 city name Qaanaaq
#  processing record: 98 | ID = 218680 city name Boende
#  processing record: 99 | ID = 3602561 city name Sambo Creek
#  processing record: 100 | ID = 4035715 city name Avarua
#  processing record: 101 | ID = 1642773 city name Japura
#  processing record: 102 | ID = 2090021 city name Namatanai
#  processing record: 103 | ID = 4131116 city name Siloam Springs
#  processing record: 104 | ID = 2737599 city name Saldanha
#  processing record: 105 | ID = 5746545 city name Portland
#  processing record: 106 | ID = 2152659 city name Port Macquarie
# No city data for : Port Macquarie
#  processing record: 107 | ID = 3466165 city name Cidreira
#  processing record: 108 | ID = 1496511 city name Novyy Urengoy
#  processing record: 109 | ID = 4791259 city name Virginia Beach
#  processing record: 110 | ID = 1336143 city name Pabna
#  processing record: 111 | ID = 2127202 city name Anadyr
#  processing record: 112 | ID = 3592642 city name Masagua
#  processing record: 113 | ID = 2022572 city name Khatanga
#  processing record: 114 | ID = 2989093 city name Ostwald
#  processing record: 115 | ID = 4501427 city name Port Elizabeth
#  processing record: 116 | ID = 3416888 city name Grindavik
#  processing record: 117 | ID = 113659 city name Tabas
#  processing record: 118 | ID = 499717 city name Rzhev
#  processing record: 119 | ID = 1014034 city name Carnarvon
#  processing record: 120 | ID = 5855927 city name Hilo
#  processing record: 121 | ID = 170017 city name Birin
#  processing record: 122 | ID = 3835994 city name Santa Rosa
#  processing record: 123 | ID = 2729907 city name Longyearbyen
#  processing record: 124 | ID = 5969025 city name Haines Junction
# No city data for : Haines Junction
#  processing record: 125 | ID = 3378644 city name Georgetown
#  processing record: 126 | ID = 3355672 city name Luderitz
#  processing record: 127 | ID = 2122090 city name Pevek
#  processing record: 128 | ID = 1015776 city name Bredasdorp
#  processing record: 129 | ID = 3369157 city name Cape Town
#  processing record: 130 | ID = 5606187 city name Saint Anthony
#  processing record: 131 | ID = 1849876 city name Yamada
#  processing record: 132 | ID = 4372777 city name Vardo
# No city data for : Vardo
#  processing record: 133 | ID = 1622318 city name Waingapu
#  processing record: 134 | ID = 1626542 city name Sorong
#  processing record: 135 | ID = 2214433 city name Nalut
#  processing record: 136 | ID = 3421765 city name Nanortalik
#  processing record: 137 | ID = 4732862 city name Nome
#  processing record: 138 | ID = 3453439 city name Ponta do Sol
#  processing record: 139 | ID = 4020109 city name Atuona
#  processing record: 140 | ID = 3778045 city name Maturin
#  processing record: 141 | ID = 2210554 city name Surt
#  processing record: 142 | ID = 1681680 city name Tiwi
#  processing record: 143 | ID = 481548 city name Troitsko-Pechorsk
#  processing record: 144 | ID = 3037456 city name Saint-Joseph
#  processing record: 145 | ID = 2163355 city name Hobart
# No city data for : Hobart
#  processing record: 146 | ID = 72181 city name Marzuq
#  processing record: 147 | ID = 2156643 city name Mount Gambier
#  processing record: 148 | ID = 3423146 city name Ilulissat
#  processing record: 149 | ID = 779554 city name Honningsvag
#  processing record: 150 | ID = 240498 city name Mongo
#  processing record: 151 | ID = 6185377 city name Yellowknife
#  processing record: 152 | ID = 2171465 city name Clarence Town
#  processing record: 153 | ID = 1059507 city name Marovoay
#  processing record: 154 | ID = 6620339 city name Karratha
#  processing record: 155 | ID = 4034551 city name Faanui
#  processing record: 156 | ID = 2160063 city name Codrington
#  processing record: 157 | ID = 5991056 city name Kenora
#  processing record: 158 | ID = 5847411 city name Kahului
#  processing record: 159 | ID = 2013921 city name Ust-Kuyga
#  processing record: 160 | ID = 5368361 city name Olga
#  processing record: 161 | ID = 3437029 city name San Patricio
#  processing record: 162 | ID = 2034600 city name Taikang
#  processing record: 163 | ID = 3870243 city name Taltal
#  processing record: 164 | ID = 3931470 city name Puerto Maldonado
#  processing record: 165 | ID = 2126199 city name Cherskiy
#  processing record: 166 | ID = 3372707 city name Ribeira Grande
#  processing record: 167 | ID = 6138310 city name Saint-Germain-de-Grantham
# No city data for : Saint-Germain-de-Grantham
#  processing record: 168 | ID = 964406 city name Port Shepstone
#  processing record: 169 | ID = 6167817 city name Torbay
#  processing record: 170 | ID = 3441684 city name Mercedes
#  processing record: 171 | ID = 1267390 city name Kavaratti
#  processing record: 172 | ID = 3583178 city name San Vicente
#  processing record: 173 | ID = 2267254 city name Lagoa
#  processing record: 174 | ID = 1633419 city name Padang
#  processing record: 175 | ID = 1486910 city name Komsomolskiy
#  processing record: 176 | ID = 2654970 city name Brae
#  processing record: 177 | ID = 2269594 city name Cascais
#  processing record: 178 | ID = 2028164 city name Deputatskiy
#  processing record: 179 | ID = 2126123 city name Chokurdakh
#  processing record: 180 | ID = 2186111 city name Ngunguru
#  processing record: 181 | ID = 934479 city name Grand Gaube
#  processing record: 182 | ID = 5779548 city name Payson
#  processing record: 183 | ID = 5880568 city name Bethel
#  processing record: 184 | ID = 569681 city name Chebsara
# No city data for : Chebsara
# No city data for : Chebsara
#  processing record: 185 | ID = 110690 city name Faya
#  processing record: 186 | ID = 4004293 city name Ixtapa
#  processing record: 187 | ID = 6322184 city name Porto Novo
#  processing record: 188 | ID = 2446796 city name Bilma
#  processing record: 189 | ID = 3156980 city name Floro
#  processing record: 190 | ID = 779330 city name Kautokeino
#  processing record: 191 | ID = 2063056 city name Port Augusta
#  processing record: 192 | ID = 1803300 city name Liuzhou
# No city data for : Liuzhou
#  processing record: 193 | ID = 2183406 city name Riwaka
#  processing record: 194 | ID = 2208425 city name Zuwarah
#  processing record: 195 | ID = 2121909 city name Poronaysk
#  processing record: 196 | ID = 1865309 city name Katsuura
#  processing record: 197 | ID = 1285173 city name Yenangyaung
#  processing record: 198 | ID = 1586350 city name Cam Ranh
#  processing record: 199 | ID = 3389822 city name Salinopolis
#  processing record: 200 | ID = 3910343 city name Mineros
#  processing record: 201 | ID = 1648636 city name Bitung
#  processing record: 202 | ID = 1273083 city name Deoli
#  processing record: 203 | ID = 3374083 city name Bathsheba
#  processing record: 204 | ID = 1067565 city name Beloha
# No city data for : Beloha
#  processing record: 205 | ID = 2335713 city name Matagami
# No city data for : Matagami
#  processing record: 206 | ID = 1651810 city name Airai
# No city data for : Airai
#  processing record: 207 | ID = 3443061 city name Chuy
#  processing record: 208 | ID = 1283217 city name Khandbari
#  processing record: 209 | ID = 2966778 city name Ballina
#  processing record: 210 | ID = 1253628 city name Lata
#  processing record: 211 | ID = 5983720 city name Iqaluit
#  processing record: 212 | ID = 3141332 city name Roros
#  processing record: 213 | ID = 3652462 city name San Cristobal
#  processing record: 214 | ID = 1152188 city name Mae Sot
# No city data for : Mae Sot
#  processing record: 215 | ID = 3356832 city name Henties Bay
#  processing record: 216 | ID = 3464724 city name Diamantino
#  processing record: 217 | ID = 2015306 city name Tiksi
#  processing record: 218 | ID = 3463478 city name SIM
#  processing record: 219 | ID = 2339937 city name Auki
#  processing record: 220 | ID = 2303611 city name Axim
#  processing record: 221 | ID = 5924351 city name Clyde River
#  processing record: 222 | ID = 3172402 city name Nago
#  processing record: 223 | ID = 1714733 city name Dingle
#  processing record: 224 | ID = 7626370 city name Bud
#  processing record: 225 | ID = 3358416 city name Bethanien
#  processing record: 226 | ID = 1488167 city name Ust-Koksa
#  processing record: 227 | ID = 1809498 city name Guilin
#  processing record: 228 | ID = 6355222 city name Yulara
#  processing record: 229 | ID = 1253628 city name Ginda
#  processing record: 230 | ID = 2337542 city name Naze
#  processing record: 231 | ID = 118704 city name Ravar
#  processing record: 232 | ID = 3531368 city name Celestun
#  processing record: 233 | ID = 543396 city name Koygorodok
#  processing record: 234 | ID = 2429344 city name Kyabe
#  processing record: 235 | ID = 4146934 city name Bayshore Gardens
#  processing record: 236 | ID = 1337612 city name Dhidhdhoo
#  processing record: 237 | ID = 344979 city name Lebu
#  processing record: 238 | ID = 3421719 city name Narsaq
#  processing record: 239 | ID = 6138908 city name Saint-Philippe
#  processing record: 240 | ID = 5961417 city name Husavik
#  processing record: 241 | ID = 2510253 city name Torrevieja
#  processing record: 242 | ID = 3664980 city name Boa Vista
#  processing record: 243 | ID = 2514651 city name Los Llanos de Aridane
# No city data for : Los Llanos de Aridane
#  processing record: 244 | ID = 2189343 city name Kaeo
#  processing record: 245 | ID = 1847947 city name Shingu
#  processing record: 246 | ID = 1267076 city name Khammam
#  processing record: 247 | ID = 1507390 city name Dikson
#  processing record: 248 | ID = 3419842 city name Sisimiut
#  processing record: 249 | ID = 2027044 city name Batagay
#  processing record: 250 | ID = 69559 city name Zabid
#  processing record: 251 | ID = 2647984 city name Great Yarmouth
#  processing record: 252 | ID = 4018320 city name El Ocotito
#  processing record: 253 | ID = 1799908 city name Nanlong
#  processing record: 254 | ID = 556268 city name Ostrovnoy
#  processing record: 255 | ID = 4033356 city name Tiarei
# No city data for : Tiarei
#  processing record: 256 | ID = 2030159 city name Bayangol
#  processing record: 257 | ID = 2038665 city name Alihe
#  processing record: 258 | ID = 4011743 city name Constitucion
#  processing record: 259 | ID = 3377301 city name Mabaruma
# No city data for : Mabaruma
#  processing record: 260 | ID = 3151056 city name Inndyr
#  processing record: 261 | ID = 1511276 city name Atagay
#  processing record: 262 | ID = 1540356 city name Raduzhnyy
#  processing record: 263 | ID = 3894426 city name Coihaique
#  processing record: 264 | ID = 477774 city name Usvyaty
#  processing record: 265 | ID = 3664716 city name Canutama
#  processing record: 266 | ID = 2092164 city name Lorengau
#  processing record: 267 | ID = 2029156 city name Suhbaatar
#  processing record: 268 | ID = 2126682 city name Bilibino
#  processing record: 269 | ID = 4231997 city name Avera
#  processing record: 270 | ID = 554830 city name Izhma
#  processing record: 271 | ID = 2079582 city name Alyangula
#  processing record: 272 | ID = 2109528 city name Buala
#  processing record: 273 | ID = 1498919 city name Lugovoy
#  processing record: 274 | ID = 2022463 city name Khilok
#  processing record: 275 | ID = 778362 city name Oksfjord
#  processing record: 276 | ID = 3522788 city name Nautla
#  processing record: 277 | ID = 3869716 city name Tocopilla
#  processing record: 278 | ID = 1106677 city name Bambous Virieux
# No city data for : Bambous Virieux
#  processing record: 279 | ID = 3397851 city name Itupiranga
#  processing record: 280 | ID = 6113365 city name Prince George
#  processing record: 281 | ID = 933077 city name Shakawe
#  processing record: 282 | ID = 2449893 city name Tessalit
#  processing record: 283 | ID = 2420826 city name Gaoual
#  processing record: 284 | ID = 2399001 city name Mayumba
#  processing record: 285 | ID = 2136825 city name Isangel
#  processing record: 286 | ID = 1264976 city name Leh
#  processing record: 287 | ID = 646006 city name Mikkeli
#  processing record: 288 | ID = 153955 city name Micheweni
#  processing record: 289 | ID = 3582228 city name Dangriga
#  processing record: 290 | ID = 2120612 city name Tigil
#  processing record: 291 | ID = 1733782 city name Victoria
# No city data for : Victoria
#  processing record: 292 | ID = 3664659 city name Carauari
#  processing record: 293 | ID = 1252783 city name Yarada
# No city data for : Yarada
#  processing record: 294 | ID = 777682 city name Skjervoy
#  processing record: 295 | ID = 3146487 city name Raudeberg
# No city data for : Raudeberg
#  processing record: 296 | ID = 535839 city name Leshukonskoye
#  processing record: 297 | ID = 2027296 city name Aykhal
#  processing record: 298 | ID = 2013639 city name Verkhnevilyuysk
# No city data for : Verkhnevilyuysk
#  processing record: 299 | ID = 3691954 city name Sechura
#  processing record: 300 | ID = 2037078 city name Hailar
#  processing record: 301 | ID = 218229 city name Bongandanga
#  processing record: 302 | ID = 2146219 city name Hervey Bay
#  processing record: 303 | ID = 2422968 city name Boffa
#  processing record: 304 | ID = 2160517 city name Launceston
#  processing record: 305 | ID = 3372472 city name Vila Franca do Campo
#  processing record: 306 | ID = 2449067 city name Timbuktu
#  processing record: 307 | ID = 5587385 city name Burley
#  processing record: 308 | ID = 5229794 city name Mitchell
#  processing record: 309 | ID = 778707 city name Mehamn
#  processing record: 310 | ID = 2012530 city name Zhigansk
#  processing record: 311 | ID = 1789647 city name Xichang
# No city data for : Xichang
#  processing record: 312 | ID = 390054 city name Baft
# No city data for : Baft
#  processing record: 313 | ID = 3347019 city name Namibe
#  processing record: 314 | ID = 4019819 city name Acaponeta
#  processing record: 315 | ID = 4015700 city name Cananea
#  processing record: 316 | ID = 1337607 city name Kudahuvadhoo
#  processing record: 317 | ID = 2258984 city name Kinkala
#  processing record: 318 | ID = 2142316 city name Yeppoon
#  processing record: 319 | ID = 3141667 city name Roald
#  processing record: 320 | ID = 3547867 city name Manzanillo
#  processing record: 321 | ID = 5883074 city name Albanel
#  processing record: 322 | ID = 2037485 city name Erenhot
#  processing record: 323 | ID = 3860443 city name Comodoro Rivadavia
#  processing record: 324 | ID = 2015913 city name Suntar
# No city data for : Suntar
#  processing record: 325 | ID = 3373652 city name Oistins
#  processing record: 326 | ID = 2318374 city name Gboko
#  processing record: 327 | ID = 2127060 city name Arman
# No city data for : Arman
#  processing record: 328 | ID = 1529484 city name Hami
#  processing record: 329 | ID = 502265 city name Mirnyy
#  processing record: 330 | ID = 933018 city name Thamaga
#  processing record: 331 | ID = 3685702 city name Cravo Norte
#  processing record: 332 | ID = 1688687 city name San Quintin
#  processing record: 333 | ID = 1695555 city name Pandan
#  processing record: 334 | ID = 787487 city name Poum
# No city data for : Poum
#  processing record: 335 | ID = 962367 city name Richards Bay
#  processing record: 336 | ID = 3105522 city name Bereda
#  processing record: 337 | ID = 4314550 city name Alexandria
#  processing record: 338 | ID = 2960970 city name Westport
#  processing record: 339 | ID = 4267710 city name Sitka
#  processing record: 340 | ID = 2128975 city name Nemuro
#  processing record: 341 | ID = 3402648 city name Carutapera
#  processing record: 342 | ID = 3430443 city name Necochea
#  processing record: 343 | ID = 1052944 city name Angoche
# No city data for : Angoche
#  processing record: 344 | ID = 1259385 city name Port Blair
#  processing record: 345 | ID = 2065594 city name Mount Isa
#  processing record: 346 | ID = 2249901 city name Gat
#  processing record: 347 | ID = 457714 city name Madona
#  processing record: 348 | ID = 1506268 city name Gornopravdinsk
#  processing record: 349 | ID = 579432 city name Balezino
# No city data for : Balezino
#  processing record: 350 | ID = 3932145 city name Pisco
#  processing record: 351 | ID = 3692072 city name Santiago de Chuco
# No city data for : Santiago de Chuco
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# OSError: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# /anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x117980518>: Failed to establish a new connection: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='api.openweathermap.org', port=80): Max retries exceeded with url: /data/2.5/weather?appid=f408a09fc8ee694ef0ac53258dbd88c2&q=soyo&units=Imperial (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x117980518>: Failed to establish a new connection: [Errno 51] Network is unreachable',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-d27437d67473> in <module>()
#      11     #print (f'processing city: {cityName}')
#      12     query_url = f"{url}appid={api_key}&q={cityName}&units={units}"
# ---> 13     response = requests.get(query_url)
#      14     data = response.json()
#      15     if data['cod']==200:
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.openweathermap.org', port=80): Max retries exceeded with url: /data/2.5/weather?appid=f408a09fc8ee694ef0ac53258dbd88c2&q=soyo&units=Imperial (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x117980518>: Failed to establish a new connection: [Errno 51] Network is unreachable',))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a csv file
# add headers
columns = [ 'Name', 'Cloudiness', 
              'Country', 'Date', 'Humidity', 
              'Lat', 'Lng', 'Max Temp', 'WindSpeed']

with open('weather.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=columns)
    writer.writeheader()
    for data in detailCity:
        writer.writerow(data)

# %%
#read csv file into a df
df = pd.read_csv("weather.csv") 
df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()

plt.scatter(df.Lat, df['Max Temp'],
            facecolor= "gold", 
            label='',
            marker='o')
          
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Temperature ")
ax.grid(True)


# Save Figure
plt.savefig('lat-v-temperature.png', bbox_inches = "tight")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()

plt.scatter(df.Lat, df.Humidity , 
            facecolor= "blue", 
            label='',
            marker='o')
          
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
ax.grid(True)


# Save Figure
plt.savefig('lat-vs-humidity.png', bbox_inches = "tight")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()

plt.scatter(df.Lat, df.Cloudiness, 
            facecolor= "green", 
            label='',
            marker='o')
          
plt.title("Latitude vs.Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
ax.grid(True)


# Save Figure
plt.savefig('lat-vs-cloudiness.png', bbox_inches = "tight")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()

plt.scatter(df.Lat, df["WindSpeed"], 
            facecolor= "red", 
            label='',
            marker='o')
          
plt.title("Latitude vs.Windspeed")
plt.xlabel("Latitude")
plt.ylabel("Windspeed")
ax.grid(True)


# Save Figure
plt.savefig('lat-vs-windspeed.png', bbox_inches = "tight")
